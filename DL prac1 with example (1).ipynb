# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
from keras import datasets 
(train_images,train_labels), (test_images,test_labels) = datasets.mnist.load_data()
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
import theano
from theano import tensor
a = tensor.dscalar('a')
b = tensor.dscalar('b')
res = a - b
func = theano.function([a,b],res)
func(30.5, 10.5)
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# array(20.)

# %%
# !pip install theano
# Out:
# Requirement already satisfied: theano in c:\users\madhura nikam\.conda\envs\newdl\lib\site-packages (1.0.5)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\madhura nikam\.conda\envs\newdl\lib\site-packages (from theano) (1.22.3)
# Requirement already satisfied: scipy>=0.14 in c:\users\madhura nikam\.conda\envs\newdl\lib\site-packages (from theano) (1.7.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\madhura nikam\.conda\envs\newdl\lib\site-packages (from theano) (1.16.0)

# %%
import numpy
import theano.tensor as T
from theano import function 
x = T.dscalar('x')
y = T.dscalar('y')
z = x + y
f = function([x,y], z)
f(5, 7)
# Out:
# array(12.)

# %%
import theano.tensor as T
from theano import function 
x = T.dmatrix('x')
y = T.dmatrix('y')
z = x + y
f = function([x,y], z)
f([[30, 50], [2, 3]], [[60, 70], [3, 4]] )
# Out:
# array([[ 90., 120.],
#        [  5.,   7.]])

# %%
import torch 
print(torch.__version__)
# Out:
# 1.12.1

# %%
a = torch.FloatTensor([2])
b = torch.FloatTensor([3])
a + b
# Out:
# tensor([5.])

# %%
matrix = torch.randn(3, 3)
matrix
# Out:
# tensor([[ 0.0912, -1.0858, -1.1417],
#         [-0.4879,  0.3020, -0.8432],
#         [ 2.5529,  0.3587,  0.8857]])

# %%
matrix.t()
# Out:
# tensor([[ 0.0912, -0.4879,  2.5529],
#         [-1.0858,  0.3020,  0.3587],
#         [-1.1417, -0.8432,  0.8857]])

# %%
import torch 
a = torch.Tensor([[1,2],[3,4]])
print(a)
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %%
print(a**2)
# Out:
# tensor([[ 1.,  4.],
#         [ 9., 16.]])

# %%
# Tensorflow and Keras Program
import tensorflow as tf 
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
x = np.array([1.0, 2.0, 3.0, 4.0, 6.0, 7.0], dtype = float) # features
y = np.array([4.0, 6.0, 8.0, 10.0, 14.0, 16.0], dtype = float) # labels

# %%
history = model.fit(x,y,epochs=50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 655ms/step - loss: 135.4401
# Epoch 2/50
# 1/1 [==============================] - 0s 8ms/step - loss: 49.2696
# Epoch 3/50
# 1/1 [==============================] - 0s 9ms/step - loss: 18.1261
# Epoch 4/50
# 1/1 [==============================] - 0s 12ms/step - loss: 6.8684
# Epoch 5/50
# 1/1 [==============================] - 0s 14ms/step - loss: 2.7973
# Epoch 6/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3232
# Epoch 7/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7877
# Epoch 8/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5914
# Epoch 9/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5177
# Epoch 10/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4884
# Epoch 11/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4751
# Epoch 12/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4676
# Epoch 13/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4622
# Epoch 14/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4577
# Epoch 15/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4534
# Epoch 16/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4493
# Epoch 17/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4453
# Epoch 18/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4413
# Epoch 19/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4373
# Epoch 20/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4334
# Epoch 21/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4295
# Epoch 22/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4257
# Epoch 23/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4219
# Epoch 24/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4181
# Epoch 25/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4144
# Epoch 26/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4107
# Epoch 27/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4070
# Epoch 28/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4033
# Epoch 29/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3997
# Epoch 30/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3961
# Epoch 31/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3926
# Epoch 32/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3891
# Epoch 33/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3856
# Epoch 34/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3822
# Epoch 35/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3787
# Epoch 36/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3753
# Epoch 37/50
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3720
# Epoch 38/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3687
# Epoch 39/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3654
# Epoch 40/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3621
# Epoch 41/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3588
# Epoch 42/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3556
# Epoch 43/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3525
# Epoch 44/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3493
# Epoch 45/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3462
# Epoch 46/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3431
# Epoch 47/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3400
# Epoch 48/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3370
# Epoch 49/50
# 1/1 [==============================] - 0s 795us/step - loss: 0.3339
# Epoch 50/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3310
